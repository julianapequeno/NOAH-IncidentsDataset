# %% [markdown]
# ## Detecting natural disasters, damage, and incidents in the wild
# > Paper: https://www.ecva.net/papers/eccv_2020/papers_ECCV/papers/123640324.pdf <br>
# > Repositório no github: https://github.com/ethanweber/IncidentsDataset/tree/master?tab=readme-ov-file

# %% [markdown]
# Setup Environment

# %%
# !git clone https://github.com/ethanweber/IncidentsDataset
# Out:
# Cloning into 'IncidentsDataset'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 201 (delta 26), reused 17 (delta 17), pack-reused 166 (from 1)
# Receiving objects: 100% (201/201), 76.70 MiB | 11.10 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
cd IncidentsDataset
# Out:
# /content/IncidentsDataset

# %%
# prompt: install conda with python 3.8.2

# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !bash ./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')
# !conda install -c conda-forge python=3.8.2
# !python --version

# %%
# !conda create -n incidents python=3.8.2

# %%
# !conda activate incidents
# Out:
# usage: conda [-h] [--no-plugins] [-V] COMMAND ...
# conda: error: argument COMMAND: invalid choice: 'activate' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'notices', 'package', 'remove', 'uninstall', 'rename', 'run', 'search', 'update', 'upgrade', 'doctor', 'content-trust', 'env')

# %%
# !conda update conda

# %%
# !ls -la

# %%
# Use conda init to properly initialize conda
# !conda init bash

# Activate the base environment (necessary after conda init)
# !source /usr/local/etc/profile.d/conda.sh

# Activate the incidents environment
# !conda activate incidents

# Update conda within the incidents environment
# !conda update -n incidents conda

# !python --version

# !conda list

# !ls -la
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.8/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# usage: conda [-h] [--no-plugins] [-V] COMMAND ...
# conda: error: argument COMMAND: invalid choice: 'activate' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'notices', 'package', 'remove', 'uninstall', 'rename', 'run', 'search', 'update', 'upgrade', 'doctor', 'env')
#
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /usr/local/envs/incidents
#   package name: conda
#
#
# Python 3.8.2
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# boltons                   23.0.0           py38h06a4308_0
# brotli-python             1.0.9            py38h6a678d5_8
# ca-certificates           2024.12.31           h06a4308_0
# certifi                   2024.8.30        py38h06a4308_0
# cffi                      1.15.0           py38hd667e15_1
# charset-normalizer        3.3.2              pyhd3eb1b0_0
# conda                     23.7.4           py38h578d9bd_0    conda-forge
# conda-package-handling    1.8.1            py38h7f8727e_0
# cryptography              36.0.0           py38h9ce1e76_0
# idna                      3.7              py38h06a4308_0
# jsonpatch                 1.33             py38h06a4308_1
# jsonpointer               2.1                pyhd3eb1b0_0
# ld_impl_linux-64          2.40                 h12ee557_0
# libffi                    3.3                  he6710b0_2
# libgcc-ng                 11.2.0               h1234567_1
# libgomp                   11.2.0               h1234567_1
# libstdcxx-ng              11.2.0               h1234567_1
# ncurses                   6.4                  h6a678d5_0
# openssl                   1.1.1w               h7f8727e_0
# packaging                 24.1             py38h06a4308_0
# pip                       24.2             py38h06a4308_0
# pluggy                    1.0.0            py38h06a4308_1
# pycosat                   0.6.6            py38h5eee18b_1
# pycparser                 2.21               pyhd3eb1b0_0
# pyopenssl                 22.0.0             pyhd3eb1b0_0
# pysocks                   1.7.1            py38h06a4308_0
# python                    3.8.2               hcff3b4d_14
# python_abi                3.8                      2_cp38    conda-forge
# readline                  8.2                  h5eee18b_0
# requests                  2.32.3           py38h06a4308_0
# ruamel.yaml               0.17.10          py38h497a2fe_0    conda-forge
# ruamel.yaml.clib          0.2.8            py38h5eee18b_0
# setuptools                75.1.0           py38h06a4308_0
# sqlite                    3.45.3               h5eee18b_0
# tk                        8.6.14               h39e8969_0
# toolz                     0.12.0           py38h06a4308_0
# tqdm                      4.66.5           py38h2f386ee_0
# urllib3                   2.2.3            py38h06a4308_0
# wheel                     0.44.0           py38h06a4308_0
# xz                        5.4.6                h5eee18b_1
# zlib                      1.2.13               h5eee18b_1
# total 78920
# drwxr-xr-x 8 root root     4096 Jan  9 16:07 .
# drwxr-xr-x 1 root root     4096 Jan  9 15:54 ..
# -rw-r--r-- 1 root root    13124 Jan  9 15:55 architectures.py
# drwxr-xr-x 2 root root     4096 Jan  9 15:55 categories
# drwxr-xr-x 2 root root     4096 Jan  9 15:55 configs
# -rw-r--r-- 1 root root     9495 Jan  9 15:55 dataset.py
# drwxr-xr-x 9 root root     4096 Jan  9 15:55 docs
# drwxr-xr-x 2 root root     4096 Jan  9 15:55 example_images
# drwxr-xr-x 8 root root     4096 Jan  9 15:55 .git
# -rw-r--r-- 1 root root     1799 Jan  9 15:55 .gitignore
# -rw-r--r-- 1 root root     1068 Jan  9 15:55 LICENSE
# -rw-r--r-- 1 root root     1886 Jan  9 15:55 loss.py
# -rw-r--r-- 1 root root    15314 Jan  9 15:55 metrics.py
# -rwxr-xr-x 1 root root 76120962 May 16  2022 Miniconda3-py38_4.12.0-Linux-x86_64.sh
# -rw-r--r-- 1 root root     5519 Jan  9 15:55 parser.py
# drwxr-xr-x 2 root root     4096 Jan  9 15:55 pretrained_weights
# -rw-r--r-- 1 root root     3965 Jan  9 15:55 README.md
# -rw-r--r-- 1 root root      203 Jan  9 15:55 requirements.txt
# -rw-r--r-- 1 root root     2872 Jan  9 15:55 run_demo_server.py
# -rw-r--r-- 1 root root      946 Jan  9 15:55 run_download_weights.py
# -rw-r--r-- 1 root root  1305103 Jan  9 15:55 RunModel.ipynb
# -rw-r--r-- 1 root root     9946 Jan  9 15:55 run_model.py
# -rw-r--r-- 1 root root     1843 Jan  9 15:55 utils.py
# -rw-r--r-- 1 root root  3250503 Jan  9 15:55 VisualizeDataset.ipynb

# %%
! source activate incidents

# %%
ls #tem que estar denrto do IncidentsDataset
# Out:
# architectures.py  loss.py                                  run_demo_server.py
# categories/       metrics.py                               run_download_weights.py
# configs/          Miniconda3-py38_4.12.0-Linux-x86_64.sh*  RunModel.ipynb
# dataset.py        parser.py                                run_model.py
# docs/             pretrained_weights/                      utils.py
# example_images/   README.md                                VisualizeDataset.ipynb
# LICENSE           requirements.txt

# %%
# !pip install -r requirements.txt

# %%
# !pip install googledrivedownloader==0.4
# Out:
# Collecting googledrivedownloader==0.4
#   Downloading googledrivedownloader-0.4-py2.py3-none-any.whl.metadata (304 bytes)
# Downloading googledrivedownloader-0.4-py2.py3-none-any.whl (3.9 kB)
# Installing collected packages: googledrivedownloader
#   Attempting uninstall: googledrivedownloader
#     Found existing installation: googledrivedownloader 1.0.0
#     Uninstalling googledrivedownloader-1.0.0:
#       Successfully uninstalled googledrivedownloader-1.0.0
# Successfully installed googledrivedownloader-0.4

# %%
# !ls
# Out:
# architectures.py  loss.py				  run_demo_server.py
# categories	  metrics.py				  run_download_weights.py
# configs		  Miniconda3-py38_4.12.0-Linux-x86_64.sh  RunModel.ipynb
# dataset.py	  parser.py				  run_model.py
# docs		  pretrained_weights			  utils.py
# example_images	  README.md				  VisualizeDataset.ipynb
# LICENSE		  requirements.txt

# %% [markdown]
# A partir deste ponto tenha certeza de que voce se encontra dentro do "IncidentsDataset/"

# %%
##usei a versão googledrivedownloader==0.4
##alterei no requirements.txt
#mudei paraa google_drive_downloader
##mudei a direção dentro do run_download_weights.py para dentro de InsidentsDataset/pretrained_weights

# %%
# !python run_download_weights.py
# Out:
#   0% 0/8 [00:00<?, ?it/s]Downloading 1HCkYHzXV-nGjRy3iehrr6y90COgG67Jh into pretrained_weights/resnet18_places365.pth.tar... Done.
#  12% 1/8 [00:04<00:31,  4.55s/it]Downloading 1NZHVWK9T-n6mjpAIjrIRtILRV2KcJAlP into pretrained_weights/resnet50_places365.pth.tar... Done.
#  25% 2/8 [00:10<00:29,  4.95s/it]Downloading 1rkCIdcA2YDGMxEoVDk79cp27HakwQLGd into pretrained_weights/eccv_baseline_model_trunk.pth.tar... Done.
#  38% 3/8 [00:15<00:24,  4.93s/it]Downloading 1jj1DJsZgPqS4u4UYOJa_xqq_1ywlinnl into pretrained_weights/eccv_baseline_model_incident.pth.tar... Done.
#  50% 4/8 [00:17<00:16,  4.13s/it]Downloading 1Tovfkt5UP3Nf5moT2QcVqRkB7Nz_D5nh into pretrained_weights/eccv_baseline_model_place.pth.tar... Done.
#  62% 5/8 [00:19<00:10,  3.53s/it]Downloading 1XbPMbKOBkj6EXjMZa4ybOezI6NMZwLOK into pretrained_weights/eccv_final_model_trunk.pth.tar... Done.
#  75% 6/8 [00:29<00:11,  5.55s/it]Downloading 1D3Nh-CqK0jTXu3fgcTwkLSIlQzgApFzu into pretrained_weights/eccv_final_model_incident.pth.tar... Done.
#  88% 7/8 [00:32<00:04,  4.54s/it]Downloading 1DbWnki2352JueF_DrnVmSVvo6bAPlf5W into pretrained_weights/eccv_final_model_place.pth.tar... Done.
# 100% 8/8 [00:34<00:00,  4.29s/it]

# %%
pip freeze
# Out:
# asttokens==3.0.0
# backcall==0.2.0
# boltons @ file:///croot/boltons_1677628692245/work
# Brotli @ file:///croot/brotli-split_1714483155106/work
# certifi @ file:///croot/certifi_1725551672989/work/certifi
# cffi @ file:///opt/conda/conda-bld/cffi_1642701102775/work
# chardet==3.0.4
# charset-normalizer @ file:///croot/charset-normalizer_1721748349566/work
# conda @ file:///home/conda/feedstock_root/build_artifacts/conda_1694556035267/work
# conda-package-handling @ file:///tmp/build/80754af9/conda-package-handling_1649087926789/work
# ConfigArgParse==1.2.3
# cryptography @ file:///tmp/build/80754af9/cryptography_1639400846433/work
# cycler==0.12.1
# decorator==5.1.1
# dill==0.3.9
# executing==2.1.0
# filelock==3.16.1
# fsspec==2024.12.0
# googledrivedownloader==1.0.0
# idna==2.10
# imageio==2.35.1
# importlib_metadata==8.5.0
# ipykernel==5.3.4
# ipython==8.12.3
# jedi==0.19.2
# Jinja2==3.1.5
# jsonpatch @ file:///croot/jsonpatch_1714483231291/work
# jsonpointer==2.1
# jupyter_client==8.6.3
# jupyter_core==5.7.2
# kiwisolver==1.4.7
# MarkupSafe==2.1.5
# matplotlib==3.3.1
# matplotlib-inline==0.1.7
# mpmath==1.3.0
# multiprocess==0.70.17
# networkx==3.1
# numpy==1.24.4
# nvidia-cublas-cu12==12.1.3.1
# nvidia-cuda-cupti-cu12==12.1.105
# nvidia-cuda-nvrtc-cu12==12.1.105
# nvidia-cuda-runtime-cu12==12.1.105
# nvidia-cudnn-cu12==9.1.0.70
# nvidia-cufft-cu12==11.0.2.54
# nvidia-curand-cu12==10.3.2.106
# nvidia-cusolver-cu12==11.4.5.107
# nvidia-cusparse-cu12==12.1.0.106
# nvidia-nccl-cu12==2.20.5
# nvidia-nvjitlink-cu12==12.6.85
# nvidia-nvtx-cu12==12.1.105
# opencv-python==4.4.0.42
# p_tqdm==1.3.3
# packaging @ file:///croot/packaging_1720101850331/work
# parso==0.8.4
# pathos==0.3.3
# pexpect==4.9.0
# pickleshare==0.7.5
# pillow==10.4.0
# platformdirs==4.3.6
# pluggy @ file:///tmp/build/80754af9/pluggy_1648042571233/work
# pox==0.3.5
# ppft==1.7.6.9
# prompt_toolkit==3.0.48
# protobuf==5.29.3
# ptyprocess==0.7.0
# pure_eval==0.2.3
# pycosat @ file:///croot/pycosat_1714510623388/work
# pycparser @ file:///tmp/build/80754af9/pycparser_1636541352034/work
# Pygments==2.19.1
# pyOpenSSL @ file:///opt/conda/conda-bld/pyopenssl_1643788558760/work
# pyparsing==3.1.4
# PySocks @ file:///tmp/build/80754af9/pysocks_1605305779399/work
# python-dateutil==2.9.0.post0
# PyWavelets==1.4.1
# pyzmq==26.2.0
# requests==2.24.0
# ruamel.yaml @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml_1624567361774/work
# ruamel.yaml.clib @ file:///croot/ruamel.yaml.clib_1727769819935/work
# scikit-image==0.17.2
# scipy==1.10.1
# six==1.17.0
# stack-data==0.6.3
# sympy==1.13.3
# tensorboardX==2.1
# tifffile==2023.7.10
# toolz @ file:///croot/toolz_1667464077321/work
# torch==2.4.1
# torchvision==0.19.1
# tornado==6.4.2
# tqdm==4.48.2
# traitlets==5.14.3
# triton==3.0.0
# typing_extensions==4.12.2
# urllib3==1.25.11
# wcwidth==0.2.13
# zipp==3.20.2

# %% [markdown]
# RUN MODEL: Script para rodar o modelo

# %%
#RUN_MODEL
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import pprint
import glob
import json
from tqdm import tqdm
import cv2
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

from architectures import (
    FilenameDataset,
    get_incidents_model,
    update_incidents_model_with_checkpoint,
    update_incidents_model_to_eval_mode,
    get_predictions_from_model
)
from parser import get_parser, get_postprocessed_args

# %%
# data
image_filenames = sorted(glob.glob("example_images/*"))
# model
CONFIG_FILENAME = "configs/eccv_final_model"
CHECKPOINT_PATH_FOLDER = "pretrained_weights/"

# %%
# you can replace the filenames with your own
image_filenames
# Out:
# ['example_images/earthquake.jpg',
#  'example_images/fire.jpg',
#  'example_images/flood.jpg',
#  'example_images/ship.jpg',
#  'example_images/ufrn.jpg']

# %%
for image_filename in image_filenames:
    img = cv2.imread(image_filename)[:,:,::-1].copy()
    plt.imshow(img)
    plt.show()

# %%
# Load model from checkpoint.
parser = get_parser()
args = parser.parse_args(args="--config={} --checkpoint_path={} --mode=test --num_gpus=0".format(CONFIG_FILENAME, CHECKPOINT_PATH_FOLDER))
args = get_postprocessed_args(args)


incidents_model = get_incidents_model(args)
update_incidents_model_with_checkpoint(incidents_model, args)
update_incidents_model_to_eval_mode(incidents_model)
# Out:
# loading places weights for pretraining
# /content/IncidentsDataset/IncidentsDataset/architectures.py:88: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_file, map_location=device)
# /content/IncidentsDataset/IncidentsDataset/architectures.py:178: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=device)
# Let's use 0 GPUs!
# eccv_final_model
# Loaded checkpoint 'pretrained_weights/eccv_final_model_trunk.pth.tar' (epoch 15).
# Loaded checkpoint 'pretrained_weights/eccv_final_model_place.pth.tar' (epoch 15).
# Loaded checkpoint 'pretrained_weights/eccv_final_model_incident.pth.tar' (epoch 15).
# Switching to eval mode.

# %%
from IncidentsDataset.utils import get_index_to_incident_mapping, get_index_to_place_mapping

# %%
# Set up the data loader for quickly loading images to run inference with.
print("num images: {}".format(len(image_filenames)))
targets = [image_filenames[i] for i in range(len(image_filenames))]
dataset = FilenameDataset(image_filenames, targets)
loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=1,
    shuffle=False,
    num_workers=4
)

inference_dict = {}
for idx, (batch_input, image_paths) in tqdm(enumerate(loader)):
    # run the model, get the output, set the inference_dict
    output = get_predictions_from_model(
        args,
        incidents_model,
        batch_input,
        image_paths,
        get_index_to_incident_mapping(),
        get_index_to_place_mapping(),
        inference_dict,
        topk=5
    )
# Out:
# num images: 5
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 5it [00:01,  3.57it/s]

# %%
for image_filename in inference_dict:
    img = cv2.imread(image_filename)[:,:,::-1].copy()
    plt.imshow(img)
    plt.show()
    pprint.pprint(inference_dict[image_filename])
# Out:
# {'incident_probs': array([9.2604744e-01, 1.1029788e-02, 4.4702897e-03, 5.2067509e-04,
#        1.9544814e-04], dtype=float32),
#  'incidents': ['earthquake',
#                'collapsed',
#                'damaged',
#                'rockslide rockfall',
#                'burned'],
#  'place_probs': array([0.26566705, 0.13693593, 0.12232043, 0.08357294, 0.07377882],
#       dtype=float32),
#  'places': ['building outdoor',
#             'street',
#             'slum',
#             'house',
#             'religious building']}
# {'incident_probs': array([0.6207943 , 0.23121072, 0.06282382, 0.04061117, 0.00209118],
#       dtype=float32),
#  'incidents': ['wildfire', 'on fire', 'fire whirl', 'burned', 'damaged'],
#  'place_probs': array([0.8459488 , 0.07128946, 0.00922022, 0.00707669, 0.00503553],
#       dtype=float32),
#  'places': ['forest', 'forest road', 'mountain', 'desert', 'highway']}
# {'incident_probs': array([9.4023949e-01, 2.7635571e-02, 5.2077989e-03, 4.5292014e-03,
#        3.0503439e-04], dtype=float32),
#  'incidents': ['flooded',
#                'tropical cyclone',
#                'storm surge',
#                'heavy rainfall',
#                'mudslide mudflow'],
#  'place_probs': array([0.37495917, 0.154944  , 0.1352714 , 0.05341304, 0.03982884],
#       dtype=float32),
#  'places': ['building outdoor', 'downtown', 'river', 'highway', 'village']}
# {'incident_probs': array([9.8649371e-01, 6.1292221e-06, 5.3839804e-06, 1.9247229e-06,
#        1.7059619e-06], dtype=float32),
#  'incidents': ['ship boat accident',
#                'storm surge',
#                'damaged',
#                'airplane accident',
#                'collapsed'],
#  'place_probs': array([0.41802362, 0.18048416, 0.07916395, 0.02241558, 0.0182332 ],
#       dtype=float32),
#  'places': ['ocean', 'beach', 'coast', 'sky', 'port']}
# {'incident_probs': array([0.06626735, 0.06203972, 0.0316683 , 0.02296901, 0.01993838],
#       dtype=float32),
#  'incidents': ['under construction',
#                'collapsed',
#                'dirty contamined',
#                'flooded',
#                'damaged'],
#  'place_probs': array([0.5848987 , 0.25527576, 0.05380514, 0.03716347, 0.02409497],
#       dtype=float32),
#  'places': ['building outdoor',
#             'dam',
#             'religious building',
#             'river',
#             'building facade']}

# %%
import torch
import pickle

# Supondo que 'incidents_model' é seu modelo treinado
with open("modelo.pkl", "wb") as f:
    pickle.dump(incidents_model, f)

print("Modelo salvo em 'modelo.pkl'")
# Out:
# Modelo salvo em 'modelo.pkl'

# %%
#Abrindo o modelo salvo em Pickle.

with open("modelo.pkl", "rb") as f:
    incidents_model = pickle.load(f)

# %%
incidents_model
# Out:
# [DataParallel(
#    (module): Sequential(
#      (0): ResNet(
#        (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (relu): ReLU(inplace=True)
#        (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#        (layer1): Sequential(
#          (0): Bottleneck(
#            (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#            (downsample): Sequential(
#              (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (1): Bottleneck(
#            (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (2): Bottleneck(
#            (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#        )
#        (layer2): Sequential(
#          (0): Bottleneck(
#            (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#            (downsample): Sequential(
#              (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#              (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (1): Bottleneck(
#            (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (2): Bottleneck(
#            (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (3): Bottleneck(
#            (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#        )
#        (layer3): Sequential(
#          (0): Bottleneck(
#            (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#            (downsample): Sequential(
#              (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#              (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (1): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (2): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (3): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (4): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (5): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#        )
#        (layer4): Sequential(
#          (0): Bottleneck(
#            (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#            (downsample): Sequential(
#              (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#              (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (1): Bottleneck(
#            (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (2): Bottleneck(
#            (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#        )
#        (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#        (fc): Linear(in_features=2048, out_features=1024, bias=True)
#      )
#      (1): ReLU()
#    )
#  ),
#  DataParallel(
#    (module): Linear(in_features=1024, out_features=43, bias=True)
#  ),
#  DataParallel(
#    (module): Linear(in_features=1024, out_features=49, bias=True)
#  )]

# %% [markdown]
# TRAINING THE MODEL

# %%
# !pip install protobuf==3.20.*
# Out:
# Collecting protobuf==3.20.*
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (679 bytes)
# Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.6 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.2
#     Uninstalling protobuf-5.29.2:
#       Successfully uninstalled protobuf-5.29.2
# Successfully installed protobuf-3.20.3

# %%
# !python -c "import torch; print(torch.cuda.is_available())"
# Out:
# True

# %%
# train the model
# !python IncidentsDataset/run_model.py --num_gpus 1 --mode=test --dataset_test example_images/ \
    --config=IncidentsDataset/configs/eccv_final_model \
    --checkpoint_path=runs/eccv_final_model

# visualize tensorboard
# !tensorboard --samples_per_plugin scalars=100,images=10 --port 8880 --bind_all --logdir IncidentsDataset/runs/eccv_final_model
# Out:
# args:
#
# Namespace(activation='sigmoid', arch='resnet50', batch_size=256, checkpoint_path='runs/eccv_final_model', config='IncidentsDataset/configs/eccv_final_model', dataset='pos_and_neg', dataset_test='example_images/', dataset_train='data/eccv_train.json', dataset_val='data/eccv_val.json', epochs=10, fc_dim=1024, ignore_places_during_training=False, images_path='data/images/', loss=None, lr=0.0001, mode='test', num_gpus=1, num_incidents=43, num_places=49, percent_of_training_set=100, pretrained=True, pretrained_with_places=True, print_freq=10, start_epoch=0, weight_decay=0.0001, workers=16)
# creating model with feature trunk architecture: 'resnet50'
# loading places weights for pretraining
# /content/IncidentsDataset/architectures.py:88: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_file, map_location=device)
# parallelizing models with 1 gpus
# eccv_final_model
# No checkpoint found at 'runs/eccv_final_model/trunk_best.pth.tar'.
# No checkpoint found at 'runs/eccv_final_model/place_best.pth.tar'.
# No checkpoint found at 'runs/eccv_final_model/incident_best.pth.tar'.
#
#
# Running in test mode
#
#
# loading test_loader
# Traceback (most recent call last):
#   File "IncidentsDataset/run_model.py", line 252, in <module>
#     main()
#   File "IncidentsDataset/run_model.py", line 203, in main
#     test_loader = get_dataset(args, is_train=False, is_test=True)
#   File "/content/IncidentsDataset/dataset.py", line 248, in get_dataset
#     incidents_images = get_loaded_json_file(args.dataset_test)
#   File "/content/IncidentsDataset/utils.py", line 64, in get_loaded_json_file
#     with open(path, "r") as fp:
# IsADirectoryError: [Errno 21] Is a directory: 'example_images/'
# 2025-01-02 19:08:36.633831: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-02 19:08:36.657142: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-02 19:08:36.666918: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-02 19:08:36.683727: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-02 19:08:37.706007: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735844919.107359   27968 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735844919.163811   27968 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735844919.164107   27968 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.17.1 at http://e2430aa9ffe4:8880/ (Press CTRL+C to quit)
# ^C
